# %% [markdown]
# ---
# layout: post
# title:  Java Setup
# description:  How to set up java
# type: issues
# comments: true
# ---

# %% [markdown]
# 1 Initial Setup - Instructions for macOS
# (For Windows, skip to section 2)
#
# To check if you have Java, type the following command in your Terminal:
#
# `java -version`
#
#
# The output of the above command should give:
# java version “X.X.X”, where X.X.X specifies the version number.
#
# If your Java version is not 17.x.x.x, then you need to get the updated version. If an error gets produced saying there is “No Java runtime present”, then you have to perform a fresh installation.
#
# 2. Download Java.
# For Macs with Intel processors, use https://download.oracle.com/java/17/latest/jdk-17_macos-x64_bin.dmg.
# For Macs with Apple Silicon processors (M1/M2), https://download.oracle.com/java/17/latest/jdk-17_macos-aarch64_bin.dmg.
#
# 3. When you’ve finished the download, click it and follow the installer. You might also have to double click the box (shown in the first photo below) to start the installer.
# ![mac1](../../../images/amc1.png)
#
# ![mac2](../../../images/mac2.png)
#
# 4. Re-run the following command in your terminal to ensure you have the correct version.
#
# `java -version`
#
# It should now give you a version number that is 17.x.x.x.

# %% [markdown]
# 2 Initial Setup - Instructions for Windows
#
# 1. To check if you have Java, type the following command in your Command Prompt:
#
# `java -version`
#
#
# The output of the above command should give:
# java version “X.X.X”, where X.X.X specifies the version number.
#
# If your Java version is not 17.x.x.x, then you need to get the updated version. If an error gets produced saying there is “No Java runtime present”, then you have to perform a fresh installation.
#
# 2. Download Java: https://download.oracle.com/java/17/latest/jdk-17_windows-x64_bin.exe
#
# 3. When you’ve finished the download, click it and follow the installer.
#
# 4. Re-run the following command in your terminal to ensure you have the correct version.
#
# java -version
#
#
# It should now give you a version number that is 17.x.x.
#
# 5. Type `javac` in the command prompt and see the output, if you get “javac is not recognized as an internal or external command”, this means the JDK Path is not set. To set it:
# Find the location of your Java folder (usually Java is installed in C:\Program Files\Java).  Go to the Java folder, and then go into the bin folder, which is inside the Java folder (usually bin is found in C:\Program Files\Java\jdk-17.0.4.1). In the bin folder you should see the files javac.exe and java.exe.  Highlight the path and copy it as shown below
#
# ![image.png](attachment:image.png)
#
# 5a. Open Control Panel and Select “System and Security”
#
# 5b. Select “System”
#
# 5c. Select “Advanced System Settings”
#
# 6. Select “Environment Variables”
#
# ![image-2.png](attachment:image-2.png)
#
# 7. Select the variable named 'Path' and press 'Edit' under the 'System Variables' section to edit the Path environment variable.
#
# ![image-3.png](attachment:image-3.png)
#
# 8. Click New and paste the path (e.g., C:\Program Files\Java\jdk-11.0.5\bin) to your Java bin folder. Click OK.
#
#
# 9. Finally, open a new command prompt window again and type `javac`. You should see something like below.
#
# > javac
# Usage: javac <options> <source files>
# where possible options include:
#   @<filename>                  Read options and filenames from file
# (and a bunch of other options below which are not shown here
